# %%
#1
import numexpr as ne
import numpy as np
import matplotlib.pyplot as plt
print("Please adhere to this syntax when entering functions: ")
print("sin(x) ---> sin(x)")
print("cos(x) ---> cos(x)")
print("sin inverse ---> arcsin(x)")
print("cos inverse ---> arccos(x)")
print("tan inverse ---> arctan(x)")
print("sinh(x) ---> sinh(x)")
print("cosh(x) ---> cosh(x)")
print("tanh(x) ---> tanh(x)")
print("arcsinh(x) ---> arcsinh(x)")
print("arccosh(x) ---> arccosh(x)")
print("arctanh(x) ---> arctanh(x)")
print("ln(x) ---> log(x)")
print("log(x) (base 10) ---> log10(x)")
print("e^x --> exp(x)")
print("|x| ---> abs(x)")
function = input("Please enter a one-dimensional function using x as the independent variable: ")
lower_x = float(input("Please enter a lower bound for x: "))
upper_x = float(input("Plase enter an upper bound for x: "))
a = np.linspace(lower_x, upper_x, 10001)
evaluated_function = ne.evaluate(function.replace("x","a"))
plt.plot(a,evaluated_function)
plt.plot(np.gradient(evaluated_function,a))
np.gradient(evaluated_function,a)
#a = np.mean(y[(x >= 4) * (x <= 7)])
#b = np.std(y[(x >= 4) * (x <= 7)])
#c = np.percentile(y[(x >= 4) * (x <= 7)], 80)
#print(a)
#print(b)
#print(c)
#plt.plot(np.gradient(y,x))
#plt.plot(np.cumsum(y)*x[1]-x[0])
# Out:
# Please adhere to this syntax when entering functions:
# sin(x) ---> sin(x)
# cos(x) ---> cos(x)
# sin inverse ---> arcsin(x)
# cos inverse ---> arccos(x)
# tan inverse ---> arctan(x)
# sinh(x) ---> sinh(x)
# cosh(x) ---> cosh(x)
# tanh(x) ---> tanh(x)
# arcsinh(x) ---> arcsinh(x)
# arccosh(x) ---> arccosh(x)
# arctanh(x) ---> arctanh(x)
# ln(x) ---> log(x)
# log(x) (base 10) ---> log10(x)
# e^x --> exp(x)
# |x| ---> abs(x)
# Please enter a one-dimensional function using x as the independent variable: sin(x**2)
# Please enter a lower bound for x: 1
# Plase enter an upper bound for x: 3
# array([ 1.08037599,  1.08014717,  1.07968925, ..., -5.4601024 ,
#        -5.46344502, -5.46511451])

# %%
#2 
nums = np.arange(0,10001)
sum(nums[(nums %4 != 0) * (nums %7 != 0)])
# Out:
# 32147142

# %%
#3
def r(t):
    return 1 + 3/4 * np.sin(3*t)

t = np.linspace(0,2*np.pi, 100000)
x = r(t)*np.cos(t)
y = r(t)*np.sin(t)
plt.plot(x,y)
A = 1/2 * sum(r(t)**2) * (t[1] - t[0])
print(A)
L = sum(np.sqrt(r(t)**2 + np.gradient(r(t),t)**2)) * t[1] - t[0]
print(L)
# Out:
# 4.025197003652634
# 11.625143180659908
